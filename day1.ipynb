# %% [markdown]
# WHY PYTHON?

# %% [markdown]
# -its case sensitive language
#
# -easy to learn
#
# -general purpose
#
# -batteries included
#
# -design philoshpy
#
# -libraries/communities

# %% [markdown]
# 1.Python Output

# %%
print('heelo world')
# Out:
# heelo world

# %%
print('my world')
# Out:
# my world

# %%
print('hello',1,2.2,True)
# Out:
# hello 1 2.2 True

# %%
print('hello',1,2.2,True,sep='%')
# Out:
# hello%1%2.2%True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('wolrd')
# Out:
# hello-wolrd

# %% [markdown]
# 2.Data Type

# %%
#INTEGERS
#1*10^308
print(2)
print(1e309)
# Out:
# 2
# inf

# %%
#decimal/float
print(2.2)
print(1.7e309)
# Out:
# 2.2
# inf

# %%
#boolean(true/false)
print(True)
print(False)
# Out:
# True
# False

# %%
#lists->arrays :an ordered, changeable (mutable) collection of items defined using square brackets [].
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#tuples :an ordered, immutable collection of items enclosed in parentheses ().
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#TEXT/STRING
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#sets: an unordered collection of unique, immutable elements.
print({1,5,4})
# Out:
# {1, 4, 5}

# %%
#dictionary:a built-in data structure that stores data in key-value pairs, allowing for efficient data retrieval and manipulation.
print({'name':'nitin','gender':'male','weight':70})
# Out:
# {'name': 'nitin', 'gender': 'male', 'weight': 70}

# %%
#type

type('world')
# Out:
# str

# %% [markdown]
# 3.VARIABLES

# %%
#variable conatins the information of unknown value 
name='nitish'
print(name)

a=5
b=6
print(a+b)
# Out:
# nitish
# 11

# %%
#dynamic typing:where there is no need to tell about the type od data( this used in python)
a=5
#static typing:its similar to C,where you have to tell about the data type 
int a=5

# %%
#dynamic binding:where in a particular program we can change the data type for a variable
a=5
print(a)
a='nitish'
print(a)
#static binding:where the data type will be same throughout the program for a variable
int a=5
# Out:
# 5
# nitish

# %%
#multiple variable (stylish declaration technique )
a=3
b=4
c=5
print(a,b,c)
# Out:
# 3 4 5

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=4
print(a,b,c)
# Out:
# 4 4 4

# %% [markdown]
# 4.Comments

# %%
#this is first comment 
a=4
b=5
print(a+b)#second comments
# Out:
# 9

# %% [markdown]
# 4.Identifiers and keywords

# %%
#keywords: this are the reserved words in python
True, False, None, and, or, not, def, class, if, else, while, for, try, except, finally, import, from, as, with, yield, del, pass, raise, return, global, nonlocal, lambda, assert, break, continue.

# %%
#Identifiers:user defined name,classes,functions 
#you cannot start with digits
name1='nitish'
print(name1)
#you can use uppercase,lowercase but in special character only '_'(underscore)no other special character
first_name ='nitish'
print(first_name)
_ = 'vishu'
print(_)
#idetifiers cannot be keywords
# Out:
# nitish
# nitish
# vishu

# %% [markdown]
# 5.User input

# %%
#static=where user donot give any kind of input only see the result like time in clock,date in calendar
#dynamic software=where users can give input and 90%people use dynamic software like youtube,ordering something in zomato

# %%
name=input("enter the name ")
print(name)
# Out:
# vishu gautam

# %%
input()
# Out:
# 'name'

# %%
#take input from users and stored in some variables
fnum=int(input('enter the first no.'))
snum=int(input('enter the second no.'))
#print(type(fnum),type(snum))
#add the 2 variables
sum=(fnum)+(snum)
#print the output
#print(sum)
print(type(fnum))
#its because string is a universal data type that why integers also stored in string so we use type conversion
#this is because the fnum inside the int is still string ,its onlu get changed in int because we tell the python to give same no. as string but in int.
#if change it in intial so its show int as type of fnum and snum
# Out:
# <class 'int'>

# %% [markdown]
# 6.Type Conversion

# %%
#implicit vs explicit 
#implicit:in which python can examine data type by itself sometimes
print(2+2.6)
print(type(2),type(2.6))
# Out:
# 4.6
# <class 'int'> <class 'float'>

# %%
#explicit:in which we tell python to convert the data type
#str->int
type(int('4'))
#we cannot add complex in integer because it will be memory loss then
# Out:
# int

# %%
#int->str
str(2)
# Out:
# '2'

# %%
#float
float(3)
# Out:
# 3.0

# %%
#type conversion doesnot change original value,its just change the new data

# %% [markdown]
# 7.Literals

# %%
# literals are the fixed values written directly in the code
a=0b1010 #binary literals
b=100 # deciaml literals
c=0o310 #octal literals
d=0x12c #hexadecimal literals

#float literals
float_1=10.5
float_2=1.5e2 #1.5*10^3
float_3=1.5e-3 #1.5*10^-3

#complex literals
x=3.14j

# %%
a=0b1010 #binary literals
print(a)
# Out:
# 10

# %%
b=100 # deciaml literals
print(b)
# Out:
# 100

# %%
c=0o310 #octal literals
print(c)
print(1.5e3)
print(1.3e-4)
# Out:
# 200
# 1500.0
# 0.00013

# %%
d=0x12c #hexadecimal literals
print(d)
x=3.14j
print(x,x.real,x.imag)
# Out:
# 300
# 3.14j 0.0 3.14

# %%
a=True +2#true=1
b=False+3 #false =0
print(a)
print(b)
# Out:
# 3
# 3

# %%
k=None
a=5
b=6
print('program exe')
#we put k=none because we cannot declare any variable early without giving any value so we print none
# Out:
# program exe
